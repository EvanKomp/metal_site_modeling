# %% [markdown]
# # Features coming out of the model should be fully equivarient, test it here

# %%
from typing import List, Dict, Any, Optional

import torch
from torch import nn
import numpy as np

import copy

# %%
NUM_CHANNELS = 64
LMAX_LIST = [3]
MMAX_LIST = [3]
NUM_HEADS = 4

NUM_RESOLUTIONS = len(LMAX_LIST)
SPHERE_CHANNELS_ALL = NUM_RESOLUTIONS * NUM_CHANNELS

# %% [markdown]
# ### 0. Load the data

# %%
from metalsitenn.dataloading import MetalSiteDataset
from metalsitenn.featurizer import MetalSiteCollator
from torch.utils.data import DataLoader
from metalsitenn.utils import visualize_protein_data_3d

# %%
ds = MetalSiteDataset(
    cache_folder='../../metal_site_modeling/data/1/1.1_parse_sites_metadata',
)

# %%
collator = MetalSiteCollator(
    atom_features=['element', 'charge', 'nhyd', 'hyb'],
    bond_features=['bond_order', 'is_in_ring', 'is_aromatic'],
    metal_unknown=False,
    metal_classification=True,
    residue_collapse_do=True,
    residue_collapse_time=0.2,
)

# %%
loader = DataLoader(
    ds,
    batch_size=1,
    collate_fn=collator,
    shuffle=True,
    num_workers=4,
)

# %%
batch = next(iter(loader))

# %%
feature_vocab_sizes = collator.featurizer.get_feature_vocab_sizes()
feature_vocab_sizes
# Out:
# {'element': 46,
#  'charge': 8,
#  'nhyd': 7,
#  'hyb': 8,
#  'bond_order': 6,
#  'is_in_ring': 3,
#  'is_aromatic': 3}

# %%
import torch
import numpy as np
from typing import Dict, Tuple
from scipy.spatial.transform import Rotation as R


def random_rotation_matrix(device: str = 'cpu') -> torch.Tensor:
    """Generate random 3x3 rotation matrix."""
    rotation = R.random()
    rot_matrix = torch.tensor(rotation.as_matrix(), dtype=torch.float64, device=device)
    return rot_matrix


def apply_rotation_to_positions(pos: torch.Tensor, rot_matrix: torch.Tensor) -> torch.Tensor:
    """Apply rotation matrix to 3D positions."""
    return torch.matmul(pos, rot_matrix.T)


def apply_translation_to_positions(pos: torch.Tensor, translation: torch.Tensor) -> torch.Tensor:
    """Apply translation vector to positions."""
    return pos + translation


def extract_scalar_features(embedding: torch.Tensor) -> torch.Tensor:
    """Extract L=0 (scalar) features from SO3 embedding.
    
    Args:
        embedding: [N, num_coefficients, channels] SO3 embedding
        
    Returns:
        Scalar features [N, channels] corresponding to L=0, m=0
    """
    # L=0 coefficients are at index 0
    return embedding[:, 0, :]


def extract_vector_features(embedding: torch.Tensor) -> torch.Tensor:
    """Extract L=1 (vector) features from SO3 embedding.
    
    Args:
        embedding: [N, num_coefficients, channels] SO3 embedding
        
    Returns:
        Vector features [N, 3, channels] corresponding to L=1, m=-1,0,1
    """
    # L=1 coefficients are at indices 1, 2, 3 (m=-1, 0, 1)
    return embedding[:, 1:4, :]

# %%
rot_matrix = random_rotation_matrix().to(torch.float64  )

# %%
rot_matrix.dtype
# Out:
# torch.float64

# %%
rot_matrix.shape
# Out:
# torch.Size([3, 3])

# %% [markdown]
# ## 1. The backbone model

# %%
from metalsitenn.nn.backbone import EquiformerWEdgesBackbone

# %%
backbone = EquiformerWEdgesBackbone(
    feature_vocab_sizes=feature_vocab_sizes,
    atom_features=['element', 'charge', 'nhyd', 'hyb'],
    bond_features=['bond_order', 'is_in_ring', 'is_aromatic'],
    embedding_dim=32,
    use_topology_gradients=False,
    use_time=False,
    lmax_list=LMAX_LIST,
    sphere_channels=NUM_CHANNELS,
    use_grid_mlp=True,
    use_s2_act_attn=False,
    use_gate_act=False,
    use_sep_s2_act=True,
    mmax_list=MMAX_LIST,
    num_layers=2, # to avoid propegating numerican precision issues
)
# Out:
# WARNING:root:Parameter 'mmax_list=[3]' is ignored in EquiformerWEdgesBackbone. Reason: Mmax list is now derived from lmax list

# %% [markdown]
# ## 2. Move all datatypes to super high precision so we don't have to deal with numerical issues

# %%
backbone = backbone.double()

for param in backbone.parameters():
    if param.dtype.is_floating_point:
        param.data = param.data.double()
for buffer in backbone.buffers():
    if buffer.dtype.is_floating_point:
        buffer.data = buffer.data.double()

# %%
batch_double = copy.deepcopy(batch)
for attr_name, attr_value in batch_double.__dict__.items():
    if isinstance(attr_value, torch.Tensor) and attr_value.dtype.is_floating_point:
        setattr(batch_double, attr_name, attr_value.double())
batch = batch_double

# %% [markdown]
# Prepare rotated batch

# %%
rotated_batch = copy.deepcopy(batch)
rotated_batch.positions.dtype
# Out:
# torch.float64

# %%
rotated_positions = apply_rotation_to_positions(batch.positions, rot_matrix)
rotated_distance_vec = rotated_positions[batch.edge_index[:,1]] - rotated_positions[batch.edge_index[:,0]]
rotated_distances = torch.norm(rotated_distance_vec, dim=1).reshape(-1, 1)

# %%
torch.testing.assert_close(rotated_distances, batch.distances, rtol=1e-5, atol=1e-5)

# %% [markdown]
# distances are the first "feature" that should be invariant and indeed they are

# %%
rotated_batch.positions = rotated_positions
rotated_batch.distance_vec = rotated_distance_vec
rotated_batch.distances = rotated_distances

# %% [markdown]
# ## 3. get outputs from original batch and rotate it

# %%
outs = backbone(batch)['node_embedding'].embedding

# %%
outs_scalers = extract_scalar_features(outs)

# %%
outs_scalers.shape
# Out:
# torch.Size([107, 64])

# %%
outs_l1 = extract_vector_features(outs)

# %% [markdown]
# ## 4. Get outs from rotated batch and compare to original batch rotated

# %%
rotated_outs = backbone(rotated_batch)['node_embedding'].embedding

# %%
rotated_outs_scalers = extract_scalar_features(rotated_outs)
rotated_outs_l1 = extract_vector_features(rotated_outs)

# %%
torch.testing.assert_close(rotated_outs_scalers, outs_scalers, rtol=1e-3, atol=1e-5)
# .1% relative error and 1e-5 absolute error is acceptable for numerical precision

# %% [markdown]
# The rotated -> model -> outs are in spherical harmonics rotated, so we just need to extract the cartesian vector features

# %%
# convert from spherical to cartesian
rotated_outs_vectors = rotated_outs_l1.permute(0, 2, 1)

# %% [markdown]
# The model -> outs are in spherical harmonics UNROTATED, so we just need to extract the cartesian vector features and then rotated

# %%
outs_l1.shape
# Out:
# torch.Size([107, 3, 64])

# %%
outs_vectors = outs_l1.permute(0, 2, 1)
outs_vectors_rotated = apply_rotation_to_positions(outs_vectors, rot_matrix)

# %%
# rtol is high because rotation can put a vector nearly parallel to an axis, leading to extremelly small components of the vector highly
# sensitive to numerical precision
, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557289534962885.addSphere({"center": {"x": -117.03792419806102, "y": -63.36548638130581, "z": 57.065720793043006}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557289534962885.addSphere({"center": {"x": -115.78591451042489, "y": -61.19891405679807, "z": 57.39323224547109}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557289534962885.addSphere({"center": {"x": -116.30161396782903, "y": -64.13260246484275, "z": 58.14224841043226}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557289534962885.addSphere({"center": {"x": -116.60669883142556, "y": -59.23161995839738, "z": 55.01690843218387}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17557289534962885.addSphere({"center": {"x

# %% [markdown]
# These are plenty accurate enough

# %% [markdown]
# ## 5. Repeat with topology gradients on

# %%
backbone = EquiformerWEdgesBackbone(
    feature_vocab_sizes=feature_vocab_sizes,
    atom_features=['element', 'charge', 'nhyd', 'hyb'],
    bond_features=['bond_order', 'is_in_ring', 'is_aromatic'],
    embedding_dim=32,
    use_topology_gradients=True,
    use_time=False,
    lmax_list=LMAX_LIST,
    sphere_channels=NUM_CHANNELS,
    mmax_list=MMAX_LIST,
    num_layers=2, # to avoid propegating numerican precision issues
)
# Out:
# WARNING:root:Parameter 'mmax_list=[3]' is ignored in EquiformerWEdgesBackbone. Reason: Mmax list is now derived from lmax list

# %%
backbone = backbone.double()

for param in backbone.parameters():
    if param.dtype.is_floating_point:
        param.data = param.data.double()
for buffer in backbone.buffers():
    if buffer.dtype.is_floating_point:
        buffer.data = buffer.data.double()

# %%
batch_double = copy.deepcopy(batch)
for attr_name, attr_value in batch_double.__dict__.items():
    if isinstance(attr_value, torch.Tensor) and attr_value.dtype.is_floating_point:
        setattr(batch_double, attr_name, attr_value.double())
batch = batch_double

# %% [markdown]
# Prepare rotated batch

# %%
rotated_batch = copy.deepcopy(batch)
rotated_batch.positions.dtype
# Out:
# torch.float64

# %%
rotated_positions = apply_rotation_to_positions(batch.positions, rot_matrix)
rotated_distance_vec = rotated_positions[batch.edge_index[:,1]] - rotated_positions[batch.edge_index[:,0]]
rotated_distances = torch.norm(rotated_distance_vec, dim=1).reshape(-1, 1)

# %%
torch.testing.assert_close(rotated_distances, batch.distances, rtol=1e-5, atol=1e-5)

# %% [markdown]
# distances are the first "feature" that should be invariant and indeed they are

# %%
rotated_batch.positions = rotated_positions
rotated_batch.distance_vec = rotated_distance_vec
rotated_batch.distances = rotated_distances

# %%
outs = backbone(batch)['node_embedding'].embedding

# %%
outs_scalers = extract_scalar_features(outs)

# %%
outs_scalers.shape
# Out:
# torch.Size([107, 64])

# %%
outs_l1 = extract_vector_features(outs)

# %%
rotated_outs = backbone(rotated_batch)['node_embedding'].embedding

# %%
rotated_outs_scalers = extract_scalar_features(rotated_outs)
rotated_outs_l1 = extract_vector_features(rotated_outs)

# %%
torch.testing.assert_close(rotated_outs_scalers, outs_scalers, rtol=1e-2, atol=1e-5)
# 1% relative error and 1e-4 absolute error is acceptable for numerical precision

# %% [markdown]
# The rotated -> model -> outs are in spherical harmonics rotated, so we just need to extract the cartesian vector features

# %%
# convert from spherical to cartesian
rotated_outs_vectors = rotated_outs_l1.permute(0, 2, 1)

# %% [markdown]
# The model -> outs are in spherical harmonics UNROTATED, so we just need to extract the cartesian vector features and then rotated

# %%
outs_l1.shape
# Out:
# torch.Size([107, 3, 64])

# %%
outs_vectors = outs_l1.permute(0, 2, 1)
outs_vectors_rotated = apply_rotation_to_positions(outs_vectors, rot_matrix)

# %%
# rtol is high because rotation can put a vector nearly parallel to an axis, leading to extremelly small components of the vector highly
# sensitive to numerical precision
torch.testing.assert_close(outs_vectors_rotated, rotated_outs_vectors, rtol=1, atol=1e-5)

# %%
# plot rotated system with output vectors
visualize_protein_data_3d(
    protein_data=rotated_batch,
    velocities=rotated_outs_vectors[:,0,:].detach(),
    velocity_scale=5)
# Out:
# <div id="3dmolviewer_1755728985559941"  style="position: relative; width: 800px; height: 600px;">
#         <p id="3dmolwarning_1755728985559941" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.0/build/3Dmol-min.js');
# }
#
# var viewer_1755728985559941 = null;
# var warn = document.getElementById("3dmolwarning_1755728985559941");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1755728985559941 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1755728985559941"),{backgroundColor:"white"});
# viewer_1755728985559941.zoomTo();
# 	viewer_1755728985559941.setBackgroundColor("white");
# 	viewer_1755728985559941.addSphere({"center": {"x": -109.3149660183159, "y": -54.420954649495194, "z": 47.664884781615754}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_1755728985559941.addSphere({"center": {"x": -110.6593787203381, "y": -54.697803547076845, "z": 48.18482094645608}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755728985559941.addSphere({"center": {"x": -110.96744496512903, "y": -56.218157314020296, "z": 48.30137295874308}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755728985559941.addSphere({"center": {"x": -111.97004034092387, "y": -56.60324865823938, "z": 48.90670966895014}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_1755728985559941.addSphere({"center": {"x": -111.72375547803375, "y": -53.94255409054993, "z": 47.35681506477105}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755728985559941.addSphere({"center": {"x": -111.84799340124765, "y": -54.45053976863339, "z": 45.887270808888104}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755728985559941.addSphere({"center": {"x": -111.45585939302494, "y": -55.61101407063087, "z": 45.5788659042737}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_1755728985559941.addSphere({"center": {"x": -112.35487037178937, "y": -53.68059611991617, "z": 45.04675604903352}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_1755728985559941.addSphere({"center": {"x": -109.92041203498526, "y": -58.26707687625341, "z": 47.980835026931594}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_1755728985559941.addSphere({"center": {"x": -109.78995236592905, "y": -58.60992884189329, "z": 47.76588399930206}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755728985559941.addSphere({"center": {"x": -110.25716227936525, "y": -58.75477137378225, "z": 47.5298001433152}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755728985559941.addSphere({"center": {"x": -110.16079588135675, "y": -58.926685746634114, "z": 47.52535367894747}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_1755728985559941.addSphere({"center": {"x": -109.83115468862243, "y": -58.81137121570056, "z": 48.17167023723772}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755728985559941.addSphere({"center": {"x": -109.59083451137484, "y": -58.78453003288213, "z": 48.033919228047765}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755728985559941.addSphere({"center": {"x": -109.51515410369788, "y": -58.59060090147582, "z": 48.328100349816815}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755728985559941.addSphere({"center": {"x": -109.28962042241658, "y": -58.379056050901646, "z": 48.35726658325412}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755728985559941.addSphere({"center": {"x": -109.13007414580169, "y": -58.73053322080823, "z": 48.255591605085236}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer
, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17557289859479237.addSphere({"center": {"x": -117.6061213229364, "y": -62.488802001598465, "z": 54.272566693701165}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17557289859479237.addSphere({"center": {"x": -117.09723885679628, "y": -61.547811472523456, "z": 55.298103058062104}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557289859479237.addSphere({"center": {"x": -116.27485621499218, "y": -60.454379277624476, "z": 54.657127681211946}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557289859479237.addSphere({"center": {"x": -115.34842601374085, "y": -60.7032280412634, "z": 53.881795455011876}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17557289859479237.addSphere({"center": {"x": -116.23789447249237, "y": -62.22541534341733, "z": 56.38094901891481}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557289859479237.addSphere({"center": {"x": -117.03792419806102, "y": -63.36548638130581, "z": 57.065720793043006}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557289859479237.addSphere({"center": {"x": -115.78591451042489, "y": -61.19891405679807, "z": 57.39323224547109}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557289859479237.addSphere({"center": {"x": -116.30161396782903, "y": -64.13260246484275, "z": 58.14224841043226}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557289859479237.addSphere({"center": {"x": -116.60669883142556, "y": -59.23161995839738, "z": 55.01690843218387}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17557289859479237.addSphere({"center": {"x

# %% [markdown]
# ## 6. Repeat but include time to make sure that the Film module doesn't mess things up ...

# %%
backbone = EquiformerWEdgesBackbone(
    feature_vocab_sizes=feature_vocab_sizes,
    atom_features=['element', 'charge', 'nhyd', 'hyb'],
    bond_features=['bond_order', 'is_in_ring', 'is_aromatic'],
    embedding_dim=32,
    num_layers=2,  # to avoid propagating numerical precision issues
    use_topology_gradients=True,
    use_time=True,  # include time to test Film module
    lmax_list=LMAX_LIST,
    sphere_channels=NUM_CHANNELS, film_basis_function='gaussian', film_num_gaussians=96)

# %%
# update precision
for param in backbone.parameters():
    if param.dtype.is_floating_point:
        param.data = param.data.double()
for buffer in backbone.buffers():
    if buffer.dtype.is_floating_point:
        buffer.data = buffer.data.double()

# %%
outs = backbone(batch)['node_embedding'].embedding
outs_scalers = extract_scalar_features(outs)
outs_l1 = extract_vector_features(outs)

# %%
rotated_outs = backbone(rotated_batch)['node_embedding'].embedding
rotated_outs_scalers = extract_scalar_features(rotated_outs)
rotated_outs_l1 = extract_vector_features(rotated_outs)

# %%
outs_vectors = outs_l1.permute(0, 2, 1)
outs_vectors_rotated = apply_rotation_to_positions(outs_vectors, rot_matrix)

# %%
rotated_outs_vectors = rotated_outs_l1.permute(0, 2, 1)

# %%
torch.testing.assert_close(outs_vectors_rotated, rotated_outs_vectors, rtol=1, atol=1e-5)

# %%
# plot rotated system with output vectors
visualize_protein_data_3d(
    protein_data=rotated_batch,
    velocities=rotated_outs_vectors[:,0,:].detach(),
    velocity_scale=10)
# Out:
# <div id="3dmolviewer_17557289903265624"  style="position: relative; width: 800px; height: 600px;">
#         <p id="3dmolwarning_17557289903265624" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.0/build/3Dmol-min.js');
# }
#
# var viewer_17557289903265624 = null;
# var warn = document.getElementById("3dmolwarning_17557289903265624");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17557289903265624 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17557289903265624"),{backgroundColor:"white"});
# viewer_17557289903265624.zoomTo();
# 	viewer_17557289903265624.setBackgroundColor("white");
# 	viewer_17557289903265624.addSphere({"center": {"x": -109.3149660183159, "y": -54.420954649495194, "z": 47.664884781615754}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17557289903265624.addSphere({"center": {"x": -110.6593787203381, "y": -54.697803547076845, "z": 48.18482094645608}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17
    feature_vocab_sizes=feature_vocab_sizes,
    atom_features=['element', 'charge', 'nhyd', 'hyb'],
    bond_features=['bond_order', 'is_in_ring', 'is_aromatic'],
    embedding_dim=32,
    num_layers=2,  # to avoid propagating numerical precision issues
    use_topology_gradients=True,
    use_time=False,  # include time to test Film module
    lmax_list=LMAX_LIST,
    sphere_channels=NUM_CHANNELS, film_basis_function='gaussian', film_num_gaussians=96,
)

# %%
for param in backbone.parameters():
    if param.dtype.is_floating_point:
        param.data = param.data.double()
for buffer in backbone.buffers():
    if buffer.dtype.is_floating_point:
        buffer.data = buffer.data.double()

# %%
from metalsitenn.nn.heads.node_prediction import NodePredictionHead

# %%
head = NodePredictionHead(
    backbone=backbone,
    output_dim=5, # arbitrary
)

# %%
# increase head precision
for param in head.parameters():
    if param.dtype.is_floating_point:
        param.data = param.data.double()
for buffer in head.buffers():
    if buffer.dtype.is_floating_point:
        buffer.data = buffer.data.double()

# %%
outs = backbone(batch)['node_embedding']
scaler_head_outs = head(outs)

# %%
rotated_outs = backbone(rotated_batch)['node_embedding']
rotated_scaler_head_outs = head(rotated_outs)

# %%
torch.testing.assert_close(rotated_scaler_head_outs, scaler_head_outs, rtol=1e-5, atol=1e-5)

# %%
feature_vocab_sizes
# Out:
# {'element': 46,
#  'charge': 8,
#  'nhyd': 7,
#  'hyb': 8,
#  'bond_order': 6,
#  'is_in_ring': 3,
#  'is_aromatic': 3}

# %% [markdown]
# ## 7. Now on wrapped model for pretraining, check losses are position independent

# %%
from metalsitenn.nn.pretrained_config import EquiformerWEdgesConfig
from metalsitenn.nn.model import EquiformerWEdgesForPretraining

# %%
collator = MetalSiteCollator(
    atom_features=['element', 'charge', 'nhyd', 'hyb'],
    bond_features=['bond_order', 'is_in_ring', 'is_aromatic'],
    metal_unknown=False,
    metal_classification=False,
    residue_collapse_do=False,
    node_mlm_do=True,
    node_mlm_rate=0.15,
    node_mlm_subrate_keep=0.1,
    node_mlm_subrate_tweak=0.1)

loader = DataLoader(
    ds,
    batch_size=1,
    collate_fn=collator,
    shuffle=True,
    num_workers=4,
)
batch = next(iter(loader))

# %%
# increase precision
batch_double = copy.deepcopy(batch)
for attr_name, attr_value in batch_double.__dict__.items():
    if isinstance(attr_value, torch.Tensor) and attr_value.dtype.is_floating_point:
        setattr(batch_double, attr_name, attr_value.double())
    elif isinstance(attr_value, torch.Tensor) and attr_value.dtype == torch.int32:
        setattr(batch_double, attr_name, attr_value.long())
batch = batch_double

# %%
config = EquiformerWEdgesConfig(
    atom_features=['element', 'charge', 'nhyd', 'hyb'],
    bond_features=['bond_order', 'is_in_ring', 'is_aromatic'],
    embedding_dim=32,
    use_topology_gradients=False,
    use_time=False,
    lmax_list=LMAX_LIST,
    sphere_channels=NUM_CHANNELS,
    use_grid_mlp=True,
    use_s2_act_attn=False,
    use_gate_act=False,
    use_sep_s2_act=True,
    mmax_list=MMAX_LIST,
    alpha_drop=0.0,
    drop_path_rate=0.0,
    feature_vocab_sizes=feature_vocab_sizes,
    num_layers=2,) # to avoid propegating numerican precision issues)

# %%
model = EquiformerWEdgesForPretraining(
    config=config)
# Out:
# WARNING:root:Parameter 'mmax_list=[3]' is ignored in EquiformerWEdgesBackbone. Reason: Mmax list is now derived from lmax list

# %%
model.eqwedges.__dict__
# Out:
# {'training': True,
#  '_parameters': OrderedDict(),
#  '_buffers': OrderedDict(),
#  '_non_persistent_buffers_set': set(),
#  '_backward_pre_hooks': OrderedDict(),
#  '_backward_hooks': OrderedDict(),
#  '_is_full_backward_hook': None,
#  '_forward_hooks': OrderedDict(),
#  '_forward_hooks_with_kwargs': OrderedDict(),
#  '_forward_hooks_always_called': OrderedDict(),
#  '_forward_pre_hooks': OrderedDict(),
#  '_forward_pre_hooks_with_kwargs': OrderedDict(),
#  '_state_dict_hooks': OrderedDict(),
#  '_state_dict_pre_hooks': OrderedDict(),
#  '_load_state_dict_pre_hooks': OrderedDict(),
#  '_load_state_dict_post_hooks': OrderedDict(),
#  '_modules': OrderedDict([('mappingReduced',
#                CoefficientMappingModule(lmax_list=[3], mmax_list=[3])),
#               ('SO3_rotation',
#                ModuleList(
#                  (0): SO3_Rotation(
#                    (mapping): CoefficientMappingModule(lmax_list=[3], mmax_list=[3])
#                  )
#                )),
#               ('SO3_grid', (3, 3)),
#               ('distance_expansion', GaussianSmearing()),
#               ('node_embedder',
#                NodeEmbedder(
#                  (embeddings): ModuleDict(
#                    (element): Embedding(46, 32)
#                    (charge): Embedding(8, 32)
#                    (nhyd): Embedding(7, 32)
#                    (hyb): Embedding(8, 32)
#                  )
#                  (projection): Linear(in_features=128, out_features=64, bias=True)
#                )),
#               ('so3_scalar_embedder', SO3ScalarEmbedder()),
#               ('edge_deg_embedding',
#                EdgeDegreeEmbedding(
#                  (SO3_rotation): ModuleList(
#                    (0): SO3_Rotation(
#                      (mapping): CoefficientMappingModule(lmax_list=[3], mmax_list=[3])
#                    )
#                  )
#                  (mappingReduced): CoefficientMappingModule(lmax_list=[3], mmax_list=[3])
#                  (rad_func): EdgeProjector(
#                    (source_embedding): NodeEmbedder(
#                      (embeddings): ModuleDict(
#                        (element): Embedding(46, 32)
#                        (charge): Embedding(8, 32)
#                        (nhyd): Embedding(7, 32)
#                        (hyb): Embedding(8, 32)
#                      )
#                      (projection): Linear(in_features=128, out_features=32, bias=True)
#                    )
#                    (destination_embedding): NodeEmbedder(
#                      (embeddings): ModuleDict(
#                        (element): Embedding(46, 32)
#                        (charge): Embedding(8, 32)
#                        (nhyd): Embedding(7, 32)
#                        (hyb): Embedding(8, 32)
#                      )
#                      (projection): Linear(in_features=128, out_features=32, bias=True)
#                    )
#                    (edge_embedding): EdgeEmbedder(
#                      (embeddings): ModuleDict(
#                        (bond_order): Embedding(6, 32)
#                        (is_in_ring): Embedding(3, 32)
#                        (is_aromatic): Embedding(3, 32)
#                      )
#                      (projection): Linear(in_features=96, out_features=32, bias=True)
#                    )
#                    (radial_func): RadialFunction(
#                      (net): Sequential(
#                        (0): Linear(in_features=608, out_features=128, bias=True)
#                        (1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#                        (2): SiLU()
#                        (3): Linear(in_features=128, out_features=128, bias=True)
#                        (4): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#                        (5): SiLU()
#                        (6): Linear(in_features=128, out_features=256, bias=True)
#                      )
#                    )
#                  )
#                )),
#               ('norm_1',
#                EquivariantLayerNormArraySphericalHarmonics(lmax=3, num_channels=64, eps=1e-05, std_balance_degrees=True)),
#               ('norm_final',
#                EquivariantLayerNormArraySphericalHarmonics(lmax=3, num_channels=64, eps=1e-05, std_balance_degrees=True)),
#               ('blocks',
#                ModuleList(
#                  (0-1): 2 x TransBlockV2WithEdges(
#                    (norm_1): EquivariantLayerNormArraySphericalHarmonics(lmax=3, num_channels=64, eps=1e-05, std_balance_degrees=True)
#                    (ga): SO2EquivariantGraphAttentionWEdgesV2(
#                      (SO3_rotation): ModuleList(
#                        (0): SO3_Rotation(
#                          (mapping): CoefficientMappingModule(lmax_list=[3], mmax_list=[3])
#                        )
#                      )
#                      (mappingReduced): CoefficientMappingModule(lmax_list=[3], mmax_list=[3])
#                      (SO3_grid): (3, 3)
#                      (edge_projector): EdgeProjector(
#                        (source_embedding): NodeEmbedder(
#                          (embeddings): ModuleDict(
#                            (element): Embedding(46, 32)
#                            (charge): Embedding(8, 32)
#                            (nhyd): Embedding(7, 32)
#                            (hyb): Embedding(8, 32)
#                          )
#                          (projection): Linear(in_features=128, out_features=32, bias=True)
#                        )
#                        (destination_embedding): NodeEmbedder(
#                          (embeddings): ModuleDict(
#                            (element): Embedding(46, 32)
#                            (charge): Embedding(8, 32)
#                            (nhyd): Embedding(7, 32)
#                            (hyb): Embedding(8, 32)
#                          )
#                          (projection): Linear(in_features=128, out_features=32, bias=True)
#                        )
#                        (edge_embedding): EdgeEmbedder(
#                          (embeddings): ModuleDict(
#                            (bond_order): Embedding(6, 32)
#                            (is_in_ring): Embedding(3, 32)
#                            (is_aromatic): Embedding(3, 32)
#                          )
#                          (projection): Linear(in_features=96, out_features=32, bias=True)
#                        )
#                      )
#                      (so2_conv_1): SO2_Convolution(
#                        (mappingReduced): CoefficientMappingModule(lmax_list=[3], mmax_list=[3])
#                        (fc_m0): Linear(in_features=512, out_features=832, bias=True)
#                        (so2_m_conv): ModuleList(
#                          (0): SO2_m_Convolution(
#                            (fc): Linear(in_features=384, out_features=384, bias=False)
#                          )
#                          (1): SO2_m_Convolution(
#                            (fc): Linear(in_features=256, out_features=256, bias=False)
#                          )
#                          (2): SO2_m_Convolution(
#                            (fc): Linear(in_features=128, out_features=128, bias=False)
#                          )
#                        )
#                        (rad_func): RadialFunction(
#                          (net): Sequential(
#                            (0): Linear(in_features=608, out_features=64, bias=True)
#                            (1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#                            (2): SiLU()
#                            (3): Linear(in_features=64, out_features=64, bias=True)
#                            (4): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#                            (5): SiLU()
#                            (6): Linear(in_features=64, out_features=1280, bias=True)
#                          )
#                        )
#                      )
#                      (alpha_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#                      (alpha_act): SmoothLeakyReLU(negative_slope=0.2)
#                      (s2_act): SeparableS2Activation(
#                        (scalar_act): SiLU()
#                        (s2_act): S2Activation(
#                          (act): SiLU()
#                        )
#                      )
#                      (so2_conv_2): SO2_Convolution(
#                        (mappingReduced): CoefficientMappingModule(lmax_list=[3], mmax_list=[3])
#                        (fc_m0): Linear(in_features=256, out_features=512, bias=True)
#                        (so2_m_conv): ModuleList(
#                          (0): SO2_m_Convolution(
#                            (fc): Linear(in_features=192, out_features=768, bias=False)
#                          )
#                          (1): SO2_m_Convolution(
#                            (fc): Linear(in_features=128, out_features=512, bias=False)
#                          )
#                          (2): SO2_m_Convolution(
#                            (fc): Linear(in_features=64, out_features=256, bias=False)
#                          )
#                        )
#                      )
#                      (proj): SO3_LinearV2(in_features=128, out_features=64, lmax=3)
#                    )
#                    (norm_2): EquivariantLayerNormArraySphericalHarmonics(lmax=3, num_channels=64, eps=1e-05, std_balance_degrees=True)
#                    (ffn): FeedForwardNetwork(
#                      (SO3_grid): (3, 3)
#                      (so3_linear_1): SO3_LinearV2(in_features=64, out_features=128, lmax=3)
#                      (scalar_mlp): Sequential(
#                        (0): Linear(in_features=64, out_features=128, bias=True)
#                        (1): SiLU()
#                      )
#                      (grid_mlp): Sequential(
#                        (0): Linear(in_features=128, out_features=128, bias=False)
#                        (1): SiLU()
#                        (2): Linear(in_features=128, out_features=128, bias=False)
#                        (3): SiLU()
#                        (4): Linear(in_features=128, out_features=128, bias=False)
#                      )
#                      (so3_linear_2): SO3_LinearV2(in_features=128, out_features=64, lmax=3)
#                    )
#                  )
#                ))]),
#  'num_layers': 2,
#  'sphere_channels': 64,
#  'attn_hidden_channels': 64,
#  'num_heads': 8,
#  'attn_alpha_channels': 64,
#  'attn_value_channels': 16,
#  'ffn_hidden_channels': 128,
#  'norm_type': 'layer_norm_sh',
#  'lmax_list': [3],
#  'grid_resolution': 18,
#  'num_sphere_samples': None,
#  'num_distance_basis': 512,
#  'edge_channels_list': [512, 64, 64],
#  'use_m_share_rad': False,
#  'distance_function': 'gaussian',
#  'attn_activation': 'silu',
#  'use_s2_act_attn': False,
#  'use_attn_renorm': True,
#  'ffn_activation': 'silu',
#  'use_gate_act': False,
#  'use_grid_mlp': True,
#  'use_sep_s2_act': True,
#  'alpha_drop': 0.0,
#  'drop_path_rate': 0.0,
#  'proj_drop': 0.0,
#  'weight_init': 'uniform',
#  'max_radius': 12.0,
#  'use_time': False,
#  'film_time_embedding_dim': 128,
#  'film_hidden_dim': 128,
#  'film_mlp_layers': 2,
#  'film_num_gaussians': 512,
#  'film_basis_function': 'gaussian',
#  'feature_vocab_sizes': {'element': 46,
#   'charge': 8,
#   'nhyd': 7,
#   'hyb': 8,
#   'bond_order': 6,
#   'is_in_ring': 3,
#   'is_aromatic': 3},
#  'atom_features': ['element', 'charge', 'nhyd', 'hyb'],
#  'bond_features': ['bond_order', 'is_in_ring', 'is_aromatic'],
#  'embedding_dim': 32,
#  'edge_degree_projector_hidden_layers': 2,
#  'edge_degree_projector_size': 128,
#  'use_topology_gradients': False,
#  'topology_gradient_clip': 100.0,
#  'num_resolutions': 1,
#  'sphere_channels_all': 64,
#  'avg_num_nodes': 100,
#  'avg_degree': 20,
#  'regress_forces': True,
#  'otf_graph': True,
#  'use_pbc': True,
#  'use_pbc_single': False,
#  'max_neighbors': 500,
#  'max_num_elements': 90,
#  'use_atom_edge_embedding': True,
#  'share_atom_edge_embedding': False,
#  'mmax_list': [3],
#  'film': None}

# %%
backbone.__dict__
# Out:
# {'training': True,
#  '_parameters': OrderedDict(),
#  '_buffers': OrderedDict(),
#  '_non_persistent_buffers_set': set(),
#  '_backward_pre_hooks': OrderedDict(),
#  '_backward_hooks': OrderedDict(),
#  '_is_full_backward_hook': None,
#  '_forward_hooks': OrderedDict(),
#  '_forward_hooks_with_kwargs': OrderedDict(),
#  '_forward_hooks_always_called': OrderedDict(),
#  '_forward_pre_hooks': OrderedDict(),
#  '_forward_pre_hooks_with_kwargs': OrderedDict(),
#  '_state_dict_hooks': OrderedDict(),
#  '_state_dict_pre_hooks': OrderedDict(),
#  '_load_state_dict_pre_hooks': OrderedDict(),
#  '_load_state_dict_post_hooks': OrderedDict(),
#  '_modules': OrderedDict([('mappingReduced',
#                CoefficientMappingModule(lmax_list=[3], mmax_list=[3])),
#               ('SO3_rotation',
#                ModuleList(
#                  (0): SO3_Rotation(
#                    (mapping): CoefficientMappingModule(lmax_list=[3], mmax_list=[3])
#                  )
#                )),
#               ('SO3_grid', (3, 3)),
#               ('distance_expansion', GaussianSmearing()),
#               ('node_embedder',
#                NodeEmbedder(
#                  (embeddings): ModuleDict(
#                    (element): Embedding(46, 32)
#                    (charge): Embedding(8, 32)
#                    (nhyd): Embedding(7, 32)
#                    (hyb): Embedding(8, 32)
#                  )
#                  (projection): Linear(in_features=128, out_features=64, bias=True)
#                )),
#               ('so3_scalar_embedder', SO3ScalarEmbedder()),
#               ('edge_deg_embedding',
#                EdgeDegreeEmbedding(
#                  (SO3_rotation): ModuleList(
#                    (0): SO3_Rotation(
#                      (mapping): CoefficientMappingModule(lmax_list=[3], mmax_list=[3])
#                    )
#                  )
#                  (mappingReduced): CoefficientMappingModule(lmax_list=[3], mmax_list=[3])
#                  (rad_func): EdgeProjector(
#                    (source_embedding): NodeEmbedder(
#                      (embeddings): ModuleDict(
#                        (element): Embedding(46, 32)
#                        (charge): Embedding(8, 32)
#                        (nhyd): Embedding(7, 32)
#                        (hyb): Embedding(8, 32)
#                      )
#                      (projection): Linear(in_features=128, out_features=32, bias=True)
#                    )
#                    (destination_embedding): NodeEmbedder(
#                      (embeddings): ModuleDict(
#                        (element): Embedding(46, 32)
#                        (charge): Embedding(8, 32)
#                        (nhyd): Embedding(7, 32)
#                        (hyb): Embedding(8, 32)
#                      )
#                      (projection): Linear(in_features=128, out_features=32, bias=True)
#                    )
#                    (edge_embedding): EdgeEmbedder(
#                      (embeddings): ModuleDict(
#                        (bond_order): Embedding(6, 32)
#                        (is_in_ring): Embedding(3, 32)
#                        (is_aromatic): Embedding(3, 32)
#                      )
#                      (projection): Linear(in_features=96, out_features=32, bias=True)
#                    )
#                    (radial_func): RadialFunction(
#                      (net): Sequential(
#                        (0): Linear(in_features=224, out_features=64, bias=True)
#                        (1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#                        (2): SiLU()
#                        (3): Linear(in_features=64, out_features=64, bias=True)
#                        (4): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#                        (5): SiLU()
#                        (6): Linear(in_features=64, out_features=256, bias=True)
#                      )
#                    )
#                  )
#                )),
#               ('norm_1',
#                EquivariantRMSNormArraySphericalHarmonicsV2(lmax=3, num_channels=64, eps=1e-05, centering=True, std_balance_degrees=True)),
#               ('norm_final',
#                EquivariantRMSNormArraySphericalHarmonicsV2(lmax=3, num_channels=64, eps=1e-05, centering=True, std_balance_degrees=True)),
#               ('blocks',
#                ModuleList(
#                  (0-1): 2 x TransBlockV2WithEdges(
#                    (norm_1): EquivariantRMSNormArraySphericalHarmonicsV2(lmax=3, num_channels=64, eps=1e-05, centering=True, std_balance_degrees=True)
#                    (ga): SO2EquivariantGraphAttentionWEdgesV2(
#                      (SO3_rotation): ModuleList(
#                        (0): SO3_Rotation(
#                          (mapping): CoefficientMappingModule(lmax_list=[3], mmax_list=[3])
#                        )
#                      )
#                      (mappingReduced): CoefficientMappingModule(lmax_list=[3], mmax_list=[3])
#                      (SO3_grid): (3, 3)
#                      (edge_projector): EdgeProjector(
#                        (source_embedding): NodeEmbedder(
#                          (embeddings): ModuleDict(
#                            (element): Embedding(46, 32)
#                            (charge): Embedding(8, 32)
#                            (nhyd): Embedding(7, 32)
#                            (hyb): Embedding(8, 32)
#                          )
#                          (projection): Linear(in_features=128, out_features=32, bias=True)
#                        )
#                        (destination_embedding): NodeEmbedder(
#                          (embeddings): ModuleDict(
#                            (element): Embedding(46, 32)
#                            (charge): Embedding(8, 32)
#                            (nhyd): Embedding(7, 32)
#                            (hyb): Embedding(8, 32)
#                          )
#                          (projection): Linear(in_features=128, out_features=32, bias=True)
#                        )
#                        (edge_embedding): EdgeEmbedder(
#                          (embeddings): ModuleDict(
#                            (bond_order): Embedding(6, 32)
#                            (is_in_ring): Embedding(3, 32)
#                            (is_aromatic): Embedding(3, 32)
#                          )
#                          (projection): Linear(in_features=96, out_features=32, bias=True)
#                        )
#                      )
#                      (so2_conv_1): SO2_Convolution(
#                        (mappingReduced): CoefficientMappingModule(lmax_list=[3], mmax_list=[3])
#                        (fc_m0): Linear(in_features=512, out_features=896, bias=True)
#                        (so2_m_conv): ModuleList(
#                          (0): SO2_m_Convolution(
#                            (fc): Linear(in_features=384, out_features=768, bias=False)
#                          )
#                          (1): SO2_m_Convolution(
#                            (fc): Linear(in_features=256, out_features=512, bias=False)
#                          )
#                          (2): SO2_m_Convolution(
#                            (fc): Linear(in_features=128, out_features=256, bias=False)
#                          )
#                        )
#                        (rad_func): RadialFunction(
#                          (net): Sequential(
#                            (0): Linear(in_features=224, out_features=64, bias=True)
#                            (1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#                            (2): SiLU()
#                            (3): Linear(in_features=64, out_features=64, bias=True)
#                            (4): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#                            (5): SiLU()
#                            (6): Linear(in_features=64, out_features=1280, bias=True)
#                          )
#                        )
#                      )
#                      (alpha_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#                      (alpha_act): SmoothLeakyReLU(negative_slope=0.2)
#                      (s2_act): SeparableS2Activation(
#                        (scalar_act): SiLU()
#                        (s2_act): S2Activation(
#                          (act): SiLU()
#                        )
#                      )
#                      (so2_conv_2): SO2_Convolution(
#                        (mappingReduced): CoefficientMappingModule(lmax_list=[3], mmax_list=[3])
#                        (fc_m0): Linear(in_features=512, out_features=512, bias=True)
#                        (so2_m_conv): ModuleList(
#                          (0): SO2_m_Convolution(
#                            (fc): Linear(in_features=384, out_features=768, bias=False)
#                          )
#                          (1): SO2_m_Convolution(
#                            (fc): Linear(in_features=256, out_features=512, bias=False)
#                          )
#                          (2): SO2_m_Convolution(
#                            (fc): Linear(in_features=128, out_features=256, bias=False)
#                          )
#                        )
#                      )
#                      (proj): SO3_LinearV2(in_features=128, out_features=64, lmax=3)
#                    )
#                    (norm_2): EquivariantRMSNormArraySphericalHarmonicsV2(lmax=3, num_channels=64, eps=1e-05, centering=True, std_balance_degrees=True)
#                    (ffn): FeedForwardNetwork(
#                      (SO3_grid): (3, 3)
#                      (so3_linear_1): SO3_LinearV2(in_features=64, out_features=512, lmax=3)
#                      (gating_linear): Linear(in_features=64, out_features=512, bias=True)
#                      (s2_act): SeparableS2Activation(
#                        (scalar_act): SiLU()
#                        (s2_act): S2Activation(
#                          (act): SiLU()
#                        )
#                      )
#                      (so3_linear_2): SO3_LinearV2(in_features=512, out_features=64, lmax=3)
#                    )
#                  )
#                )),
#               ('topology_mixer',
#                SO3_L1_LinearMixing(
#                  (linears): ModuleList(
#                    (0-1): 2 x SO3_L1_Linear()
#                  )
#                ))]),
#  'num_layers': 2,
#  'sphere_channels': 64,
#  'attn_hidden_channels': 128,
#  'num_heads': 8,
#  'attn_alpha_channels': 32,
#  'attn_value_channels': 16,
#  'ffn_hidden_channels': 512,
#  'norm_type': 'rms_norm_sh',
#  'lmax_list': [3],
#  'grid_resolution': None,
#  'num_sphere_samples': 128,
#  'num_distance_basis': 128,
#  'edge_channels_list': [128, 64, 64],
#  'use_m_share_rad': False,
#  'distance_function': 'gaussian',
#  'attn_activation': 'scaled_silu',
#  'use_s2_act_attn': False,
#  'use_attn_renorm': True,
#  'ffn_activation': 'scaled_silu',
#  'use_gate_act': False,
#  'use_grid_mlp': False,
#  'use_sep_s2_act': True,
#  'alpha_drop': 0.0,
#  'drop_path_rate': 0.0,
#  'proj_drop': 0.0,
#  'weight_init': 'uniform',
#  'max_radius': 5.0,
#  'use_time': False,
#  'film_time_embedding_dim': 128,
#  'film_hidden_dim': 256,
#  'film_mlp_layers': 2,
#  'film_num_gaussians': 96,
#  'film_basis_function': 'gaussian',
#  'feature_vocab_sizes': {'element': 46,
#   'charge': 8,
#   'nhyd': 7,
#   'hyb': 8,
#   'bond_order': 6,
#   'is_in_ring': 3,
#   'is_aromatic': 3},
#  'atom_features': ['element', 'charge', 'nhyd', 'hyb'],
#  'bond_features': ['bond_order', 'is_in_ring', 'is_aromatic'],
#  'embedding_dim': 32,
#  'edge_degree_projector_hidden_layers': 2,
#  'edge_degree_projector_size': 64,
#  'use_topology_gradients': True,
#  'topology_gradient_clip': 100.0,
#  'num_resolutions': 1,
#  'sphere_channels_all': 64,
#  'avg_num_nodes': 77.81317,
#  'avg_degree': 23.395238876342773,
#  'regress_forces': True,
#  'otf_graph': True,
#  'use_pbc': True,
#  'use_pbc_single': False,
#  'max_neighbors': 500,
#  'max_num_elements': 90,
#  'use_atom_edge_embedding': True,
#  'share_atom_edge_embedding': False,
#  'mmax_list': None,
#  'film': None}

# %%
for key, val in model.eqwedges.__dict__.items():
    if key.startswith('_'):
        continue
    if isinstance(val, nn.Module):
        pass
    if backbone.__dict__[key] is val:
        pass
    elif backbone.__dict__[key] == val:
        pass
    else:
        print(f"Key {key} does not match between model and backbone: {backbone.__dict__[key]} vs {val}")
# Out:
# Key attn_hidden_channels does not match between model and backbone: 128 vs 64
# Key attn_alpha_channels does not match between model and backbone: 32 vs 64
# Key ffn_hidden_channels does not match between model and backbone: 512 vs 128
# Key norm_type does not match between model and backbone: rms_norm_sh vs layer_norm_sh
# Key grid_resolution does not match between model and backbone: None vs 18
# Key num_sphere_samples does not match between model and backbone: 128 vs None
# Key num_distance_basis does not match between model and backbone: 128 vs 512
# Key edge_channels_list does not match between model and backbone: [128, 64, 64] vs [512, 64, 64]
# Key attn_activation does not match between model and backbone: scaled_silu vs silu
# Key ffn_activation does not match between model and backbone: scaled_silu vs silu
# Key use_grid_mlp does not match between model and backbone: False vs True
# Key max_radius does not match between model and backbone: 5.0 vs 12.0
# Key film_hidden_dim does not match between model and backbone: 256 vs 128
# Key film_num_gaussians does not match between model and backbone: 96 vs 512
# Key edge_degree_projector_size does not match between model and backbone: 64 vs 128
# Key use_topology_gradients does not match between model and backbone: True vs False
# Key avg_num_nodes does not match between model and backbone: 77.81317 vs 100
# Key avg_degree does not match between model and backbone: 23.395238876342773 vs 20
# Key mmax_list does not match between model and backbone: None vs [3]

# %%
# update precision
for param in model.parameters():
    if param.dtype.is_floating_point:
        param.data = param.data.double()
for buffer in model.buffers():
    if buffer.dtype.is_floating_point:
        buffer.data = buffer.data.double()

# %%
outs = model(batch, compute_loss=True, return_node_embedding_tensor=True)

# %%
embeddings = outs.node_embeddings
scalers = extract_scalar_features(embeddings)

# %%
logits = outs.node_logits
loss = outs.loss
loss
# Out:
# tensor(4.0268, dtype=torch.float64, grad_fn=<DivBackward0>)

# %%
rotated_batch = copy.deepcopy(batch)
rotated_positions = apply_rotation_to_positions(batch.positions, rot_matrix)
rotated_distance_vec = rotated_positions[batch.edge_index[:,1]] - rotated_positions[batch.edge_index[:,0]]
rotated_distances = torch.norm(rotated_distance_vec, dim=1).reshape(-1, 1)

# %%
rotated_batch.positions = rotated_positions
rotated_batch.distance_vec = rotated_distance_vec
rotated_batch.distances = rotated_distances

# %%
rotated_outs = model(rotated_batch, compute_loss=True, return_node_embedding_tensor=True)

# %%
rotated_embeddings = rotated_outs.node_embeddings
rotated_scalers = extract_scalar_features(rotated_embeddings)

# %%
rotated_logits = rotated_outs.node_logits
rotated_loss = rotated_outs.loss
rotated_loss
# Out:
# tensor(4.0268, dtype=torch.float64, grad_fn=<DivBackward0>)

# %%
torch.testing.assert_close(loss, rotated_loss, rtol=1e-3, atol=1e-5)

# %%
torch.testing.assert_close(scalers, rotated_scalers, rtol=1e-3, atol=1e-5)

# %%
torch.testing.assert_close(logits, rotated_logits, rtol=1e-3, atol=1e-5)
