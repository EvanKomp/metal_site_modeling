# %% [markdown]
# # Features coming out of the model should be fully equivarient, test it here

# %%
from typing import List, Dict, Any, Optional

import torch
from torch import nn
import numpy as np

import copy

# %%
NUM_CHANNELS = 64
LMAX_LIST = [3]
MMAX_LIST = [3]
NUM_HEADS = 4

NUM_RESOLUTIONS = len(LMAX_LIST)
SPHERE_CHANNELS_ALL = NUM_RESOLUTIONS * NUM_CHANNELS

# %% [markdown]
# ### 0. Load the data

# %%
from metalsitenn.dataloading import MetalSiteDataset
from metalsitenn.featurizer import MetalSiteCollator
from torch.utils.data import DataLoader
from metalsitenn.utils import visualize_protein_data_3d

# %%
ds = MetalSiteDataset(
    cache_folder='../../metal_site_modeling/data/1/1.1_parse_sites_metadata',
)

# %%
collator = MetalSiteCollator(
    atom_features=['element', 'charge', 'nhyd', 'hyb'],
    bond_features=['bond_order', 'is_in_ring', 'is_aromatic'],
    metal_unknown=False,
    metal_classification=True,
    residue_collapse_do=True,
    residue_collapse_time=0.2,
)

# %%
loader = DataLoader(
    ds,
    batch_size=1,
    collate_fn=collator,
    shuffle=True,
    num_workers=4,
)

# %%
batch = next(iter(loader))

# %%
feature_vocab_sizes = collator.featurizer.get_feature_vocab_sizes()
feature_vocab_sizes
# Out:
# {'element': 46,
#  'charge': 8,
#  'nhyd': 7,
#  'hyb': 8,
#  'bond_order': 6,
#  'is_in_ring': 3,
#  'is_aromatic': 3}

# %%
import torch
import numpy as np
from typing import Dict, Tuple
from scipy.spatial.transform import Rotation as R


def random_rotation_matrix(device: str = 'cpu') -> torch.Tensor:
    """Generate random 3x3 rotation matrix."""
    rotation = R.random()
    rot_matrix = torch.tensor(rotation.as_matrix(), dtype=torch.float64, device=device)
    return rot_matrix


def apply_rotation_to_positions(pos: torch.Tensor, rot_matrix: torch.Tensor) -> torch.Tensor:
    """Apply rotation matrix to 3D positions."""
    return torch.matmul(pos, rot_matrix.T)


def apply_translation_to_positions(pos: torch.Tensor, translation: torch.Tensor) -> torch.Tensor:
    """Apply translation vector to positions."""
    return pos + translation


def extract_scalar_features(embedding: torch.Tensor) -> torch.Tensor:
    """Extract L=0 (scalar) features from SO3 embedding.
    
    Args:
        embedding: [N, num_coefficients, channels] SO3 embedding
        
    Returns:
        Scalar features [N, channels] corresponding to L=0, m=0
    """
    # L=0 coefficients are at index 0
    return embedding[:, 0, :]


def extract_vector_features(embedding: torch.Tensor) -> torch.Tensor:
    """Extract L=1 (vector) features from SO3 embedding.
    
    Args:
        embedding: [N, num_coefficients, channels] SO3 embedding
        
    Returns:
        Vector features [N, 3, channels] corresponding to L=1, m=-1,0,1
    """
    # L=1 coefficients are at indices 1, 2, 3 (m=-1, 0, 1)
    return embedding[:, 1:4, :]

# %%
rot_matrix = random_rotation_matrix().to(torch.float64  )

# %%
rot_matrix.dtype
# Out:
# torch.float64

# %%
rot_matrix.shape
# Out:
# torch.Size([3, 3])

# %% [markdown]
# ## 1. The backbone model

# %%
from metalsitenn.nn.backbone import EquiformerWEdgesBackbone

# %%
backbone = EquiformerWEdgesBackbone(
    feature_vocab_sizes=feature_vocab_sizes,
    atom_features=['element', 'charge', 'nhyd', 'hyb'],
    bond_features=['bond_order', 'is_in_ring', 'is_aromatic'],
    embedding_dim=32,
    use_topology_gradients=True,
    use_time=False,
    lmax_list=LMAX_LIST,
    sphere_channels=NUM_CHANNELS,
    mmax_list=MMAX_LIST,
    num_layers=2, # to avoid propegating numerican precision issues
)
# Out:
# WARNING:root:Parameter 'mmax_list=[3]' is ignored in EquiformerWEdgesBackbone. Reason: Mmax list is now derived from lmax list

# %% [markdown]
# ## 2. Move all datatypes to super high precision so we don't have to deal with numerical issues

# %%
backbone = backbone.double()

for param in backbone.parameters():
    if param.dtype.is_floating_point:
        param.data = param.data.double()
for buffer in backbone.buffers():
    if buffer.dtype.is_floating_point:
        buffer.data = buffer.data.double()

# %%
batch_double = copy.deepcopy(batch)
for attr_name, attr_value in batch_double.__dict__.items():
    if isinstance(attr_value, torch.Tensor) and attr_value.dtype.is_floating_point:
        setattr(batch_double, attr_name, attr_value.double())
batch = batch_double

# %% [markdown]
# Prepare rotated batch

# %%
rotated_batch = copy.deepcopy(batch)
rotated_batch.positions.dtype
# Out:
# torch.float64

# %%
rotated_positions = apply_rotation_to_positions(batch.positions, rot_matrix)
rotated_distance_vec = rotated_positions[batch.edge_index[:,1]] - rotated_positions[batch.edge_index[:,0]]
rotated_distances = torch.norm(rotated_distance_vec, dim=1).reshape(-1, 1)

# %%
torch.testing.assert_close(rotated_distances, batch.distances, rtol=1e-5, atol=1e-5)

# %% [markdown]
# distances are the first "feature" that should be invariant and indeed they are

# %%
rotated_batch.positions = rotated_positions
rotated_batch.distance_vec = rotated_distance_vec
rotated_batch.distances = rotated_distances

# %% [markdown]
# ## 3. get outputs from original batch and rotate it

# %%
outs = backbone(batch)['node_embedding'].embedding

# %%
backbone.topology_mixer.linears[0].weight.dtype
# Out:
# torch.float64

# %%
outs_scalers = extract_scalar_features(outs)

# %%
outs_scalers.shape
# Out:
# torch.Size([80, 64])

# %%
outs_l1 = extract_vector_features(outs)

# %% [markdown]
# ## 4. Get outs from rotated batch and compare to original batch rotated

# %%
rotated_outs = backbone(rotated_batch)['node_embedding'].embedding

# %%
rotated_outs_scalers = extract_scalar_features(rotated_outs)
rotated_outs_l1 = extract_vector_features(rotated_outs)

# %%
torch.testing.assert_close(rotated_outs_scalers, outs_scalers, rtol=1e-2, atol=1e-4)
# 1% relative error and 1e-4 absolute error is acceptable for numerical precision

# %% [markdown]
# The rotated -> model -> outs are in spherical harmonics rotated, so we just need to extract the cartesian vector features

# %%
# convert from spherical to cartesian
rotated_outs_vectors = rotated_outs_l1.permute(0, 2, 1)

# %% [markdown]
# The model -> outs are in spherical harmonics UNROTATED, so we just need to extract the cartesian vector features and then rotated

# %%
outs_l1.shape
# Out:
# torch.Size([80, 3, 64])

# %%
outs_vectors = outs_l1.permute(0, 2, 1)
outs_vectors_rotated = apply_rotation_to_positions(outs_vectors, rot_matrix)

# %%
# rtol is high because rotation can put a vector nearly parallel to an axis, leading to extremelly small components of the vector highly
# sensitive to numerical precision
torch.testing.assert_close(outs_vectors_rotated, rotated_outs_vectors, rtol=1, atol=1e-3)

# %%
outs_vectors_rotated[63,50]
# Out:
# tensor([ 0.1998, -0.7565,  0.8081], dtype=torch.float64,
#        grad_fn=<SelectBackward0>)

# %%
rotated_outs_vectors[63,50]
# Out:
# tensor([ 0.1998, -0.7566,  0.8080], dtype=torch.float64,
#        grad_fn=<SelectBackward0>)

# %%
# plot rotated system with output vectors
visualize_protein_data_3d(
    protein_data=rotated_batch,
    velocities=rotated_outs_vectors[:,0,:].detach(),
    velocity_scale=5)
# Out:
# <div id="3dmolviewer_17556511146876798"  style="position: relative; width: 800px; height: 600px;">
#         <p id="3dmolwarning_17556511146876798" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.0/build/3Dmol-min.js');
# }
#
# var viewer_17556511146876798 = null;
# var warn = document.getElementById("3dmolwarning_17556511146876798");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17556511146876798 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17556511146876798"),{backgroundColor:"white"});
# viewer_17556511146876798.zoomTo();
# 	viewer_17556511146876798.setBackgroundColor("white");
# 	viewer_17556511146876798.addSphere({"center": {"x": -19.850378876009213, "y": -13.397546460334867, "z": -12.446210980619062}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -19.3599889362384, "y": -12.133717738928496, "z": -13.072597790193878}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -18.332942204763494, "y": -11.45662544034617, "z": -12.160560609254233}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -18.39216514153789, "y": -11.572374372538981, "z": -10.951879408161034}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -20.603269515438107, "y": -11.257285719940414, "z": -13.225769135729772}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -21.604813120297397, "y": -11.949744646465911, "z": -14.152888704558476}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -22.825115707942967, "y": -11.047669675456358, "z": -14.364407566108152}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -22.93417068830916, "y": -10.052460939934619, "z": -13.665917004327932}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -23.630630410102555, "y": -11.369076353925736, "z": -15.221843259306056}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -16.049425902732242, "y": -10.436592405707518, "z": -11.987422277744457}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -16.021591299558914, "y": -10.360632184754296, "z": -11.77578944624168}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -16.04803261006979, "y": -9.976355143471018, "z": -11.755501614616248}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -16.267794220760887, "y": -10.091843724483624, "z": -12.022100034708426}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -15.549457619609964, "y": -10.500361737669369, "z": -11.962108328309563}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -15.556333061192369, "y": -10.705588972667469, "z": -11.664077431519814}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -15.660100810622225, "y": -10.885063858824138, "z": -11.851269895711448}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -15.593517871144824, "y": -10.821290112330248, "z": -11.496945954145838}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -15.530440948539626, "y": -11.025611663425787, "z": -12.104694976296159}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -15.535947277982894, "y": -10.98063269806285, "z": -11.252827567378535}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -15.601263497307256, "y": -11.327106404357435, "z": -11.90529370872934}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -16.46399890231644, "y": -6.47972628707001, "z": -11.168792231128878}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -16.184761402522167, "y": -6.274520931565279, "z": -11.161113868259504}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -16.156451558183964, "y": -6.149759105087859, "z": -11.329512288739195}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -15.64338102110157, "y": -5.665890079733453, "z": -11.394222137051429}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -16.395527421523646, "y": -6.2363785061897845, "z": -10.677960963764894}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -16.356314938437873, "y": -6.402986322984209, "z": -10.986994077200244}, "radius": 0.3, "color": "yellow", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -14.327370327425681, "y": -6.418650094148393, "z": -10.005682856323244}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -12.922322413375376, "y": -5.945107391622302, "z": -9.990879195091214}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -12.060806562251722, "y": -7.085328716578731, "z": -9.443526645808813}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -12.588121836918589, "y": -8.13847132191538, "z": -9.14018414627878}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -12.922690117602638, "y": -4.710649866491725, "z": -9.075065969939306}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -13.59558659151408, "y": -4.9939810761996215, "z": -7.757763215085032}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -13.344536488643055, "y": -6.133123152171455, "z": -7.007756593531021}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -14.501429665288756, "y": -4.26287009838896, "z": -7.035921917374295}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -14.089660017391957, "y": -6.051461828567259, "z": -5.889266952201101}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -14.815435505645388, "y": -4.931604846655178, "z": -5.856534253987477}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17556511146876798.addSphere({"center": {"x": -13.03466637691458, "y": -10.31755045970509, "z": -6.535145878335913}, "radius": 0.3, "color": "blue", "alpha":

# %%
visualize_protein_data_3d(
    protein_data=rotated_batch,
    velocities=outs_vectors_rotated[:,0,:].detach(),
    velocity_scale=5)
# Out:
# <div id="3dmolviewer_17556511147377331"  style="position: relative; width: 800px; height: 600px;">
#         <p id="3dmolwarning_17556511147377331" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.0/build/3Dmol-min.js');
# }
#
# var viewer_17556511147377331 = null;
# var warn = document.getElementById("3dmolwarning_17556511147377331");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17556511147377331 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17556511147377331"),{backgroundColor:"white"});
# viewer_17556511147377331.zoomTo();
# 	viewer_17556511147377331.setBackgroundColor("white");
# 	viewer_17556511147377331.addSphere({"center": {"x": -19.850378876009213, "y": -13.397546460334867, "z": -12.446210980619062}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -19.3599889362384, "y": -12.133717738928496, "z": -13.072597790193878}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -18.332942204763494, "y": -11.45662544034617, "z": -12.160560609254233}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -18.39216514153789, "y": -11.572374372538981, "z": -10.951879408161034}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -20.603269515438107, "y": -11.257285719940414, "z": -13.225769135729772}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -21.604813120297397, "y": -11.949744646465911, "z": -14.152888704558476}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -22.825115707942967, "y": -11.047669675456358, "z": -14.364407566108152}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -22.93417068830916, "y": -10.052460939934619, "z": -13.665917004327932}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -23.630630410102555, "y": -11.369076353925736, "z": -15.221843259306056}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -16.049425902732242, "y": -10.436592405707518, "z": -11.987422277744457}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -16.021591299558914, "y": -10.360632184754296, "z": -11.77578944624168}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -16.04803261006979, "y": -9.976355143471018, "z": -11.755501614616248}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -16.267794220760887, "y": -10.091843724483624, "z": -12.022100034708426}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -15.549457619609964, "y": -10.500361737669369, "z": -11.962108328309563}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -15.556333061192369, "y": -10.705588972667469, "z": -11.664077431519814}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -15.660100810622225, "y": -10.885063858824138, "z": -11.851269895711448}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -15.593517871144824, "y": -10.821290112330248, "z": -11.496945954145838}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -15.530440948539626, "y": -11.025611663425787, "z": -12.104694976296159}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -15.535947277982894, "y": -10.98063269806285, "z": -11.252827567378535}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -15.601263497307256, "y": -11.327106404357435, "z": -11.90529370872934}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -16.46399890231644, "y": -6.47972628707001, "z": -11.168792231128878}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -16.184761402522167, "y": -6.274520931565279, "z": -11.161113868259504}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -16.156451558183964, "y": -6.149759105087859, "z": -11.329512288739195}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -15.64338102110157, "y": -5.665890079733453, "z": -11.394222137051429}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -16.395527421523646, "y": -6.2363785061897845, "z": -10.677960963764894}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -16.356314938437873, "y": -6.402986322984209, "z": -10.986994077200244}, "radius": 0.3, "color": "yellow", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -14.327370327425681, "y": -6.418650094148393, "z": -10.005682856323244}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -12.922322413375376, "y": -5.945107391622302, "z": -9.990879195091214}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -12.060806562251722, "y": -7.085328716578731, "z": -9.443526645808813}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -12.588121836918589, "y": -8.13847132191538, "z": -9.14018414627878}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -12.922690117602638, "y": -4.710649866491725, "z": -9.075065969939306}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -13.59558659151408, "y": -4.9939810761996215, "z": -7.757763215085032}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -13.344536488643055, "y": -6.133123152171455, "z": -7.007756593531021}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -14.501429665288756, "y": -4.26287009838896, "z": -7.035921917374295}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -14.089660017391957, "y": -6.051461828567259, "z": -5.889266952201101}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -14.815435505645388, "y": -4.931604846655178, "z": -5.856534253987477}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17556511147377331.addSphere({"center": {"x": -13.03466637691458, "y": -10.31755045970509, "z": -6.535145878335913}, "radius": 0.3, "color": "blue", "alpha":

# %% [markdown]
# These are plenty accurate enough

# %% [markdown]
# ## 5. Repeat but make include time to make sure that the Film module doesn't mess things up ...

# %%
backbone = EquiformerWEdgesBackbone(
    feature_vocab_sizes=feature_vocab_sizes,
    atom_features=['element', 'charge', 'nhyd', 'hyb'],
    bond_features=['bond_order', 'is_in_ring', 'is_aromatic'],
    embedding_dim=32,
    use_topology_gradients=True,
    use_time=True,  # include time to test Film module
    lmax_list=LMAX_LIST,
    sphere_channels=NUM_CHANNELS, film_basis_function='gaussian')

# %%
# update precision
for param in backbone.parameters():
    if param.dtype.is_floating_point:
        param.data = param.data.double()
for buffer in backbone.buffers():
    if buffer.dtype.is_floating_point:
        buffer.data = buffer.data.double()

# %%
outs = backbone(batch)['node_embedding'].embedding
outs_scalers = extract_scalar_features(outs)
outs_l1 = extract_vector_features(outs)

# %%
rotated_outs = backbone(rotated_batch)['node_embedding'].embedding
rotated_outs_scalers = extract_scalar_features(rotated_outs)
rotated_outs_l1 = extract_vector_features(rotated_outs)

# %%
outs_vectors = outs_l1.permute(0, 2, 1)
outs_vectors_rotated = apply_rotation_to_positions(outs_vectors, rot_matrix)

# %%
rotated_outs_vectors = rotated_outs_l1.permute(0, 2, 1)

# %%
torch.testing.assert_close(outs_vectors_rotated, rotated_outs_vectors, rtol=1, atol=1e-3)
