# %% [markdown]
# # Features coming out of the model should be fully equivarient, test it here

# %%
from typing import List, Dict, Any, Optional

import torch
from torch import nn
import numpy as np

import copy

# %%
NUM_CHANNELS = 64
LMAX_LIST = [3]
MMAX_LIST = [3]
NUM_HEADS = 4

NUM_RESOLUTIONS = len(LMAX_LIST)
SPHERE_CHANNELS_ALL = NUM_RESOLUTIONS * NUM_CHANNELS

# %% [markdown]
# ### 0. Load the data

# %%
from metalsitenn.dataloading import MetalSiteDataset
from metalsitenn.featurizer import MetalSiteCollator
from torch.utils.data import DataLoader
from metalsitenn.utils import visualize_protein_data_3d

# %%
ds = MetalSiteDataset(
    cache_folder='../../metal_site_modeling/data/1/1.1_parse_sites_metadata',
)

# %%
collator = MetalSiteCollator(
    atom_features=['element', 'charge', 'nhyd', 'hyb'],
    bond_features=['bond_order', 'is_in_ring', 'is_aromatic'],
    metal_unknown=False,
    metal_classification=True,
    residue_collapse_do=True,
    residue_collapse_time=0.2,
)

# %%
loader = DataLoader(
    ds,
    batch_size=1,
    collate_fn=collator,
    shuffle=True,
    num_workers=4,
)

# %%
batch = next(iter(loader))

# %%
feature_vocab_sizes = collator.featurizer.get_feature_vocab_sizes()
feature_vocab_sizes
# Out:
# {'element': 46,
#  'charge': 8,
#  'nhyd': 7,
#  'hyb': 8,
#  'bond_order': 6,
#  'is_in_ring': 3,
#  'is_aromatic': 3}

# %%
import torch
import numpy as np
from typing import Dict, Tuple
from scipy.spatial.transform import Rotation as R


def random_rotation_matrix(device: str = 'cpu') -> torch.Tensor:
    """Generate random 3x3 rotation matrix."""
    rotation = R.random()
    rot_matrix = torch.tensor(rotation.as_matrix(), dtype=torch.float64, device=device)
    return rot_matrix


def apply_rotation_to_positions(pos: torch.Tensor, rot_matrix: torch.Tensor) -> torch.Tensor:
    """Apply rotation matrix to 3D positions."""
    return torch.matmul(pos, rot_matrix.T)


def apply_translation_to_positions(pos: torch.Tensor, translation: torch.Tensor) -> torch.Tensor:
    """Apply translation vector to positions."""
    return pos + translation


def extract_scalar_features(embedding: torch.Tensor) -> torch.Tensor:
    """Extract L=0 (scalar) features from SO3 embedding.
    
    Args:
        embedding: [N, num_coefficients, channels] SO3 embedding
        
    Returns:
        Scalar features [N, channels] corresponding to L=0, m=0
    """
    # L=0 coefficients are at index 0
    return embedding[:, 0, :]


def extract_vector_features(embedding: torch.Tensor) -> torch.Tensor:
    """Extract L=1 (vector) features from SO3 embedding.
    
    Args:
        embedding: [N, num_coefficients, channels] SO3 embedding
        
    Returns:
        Vector features [N, 3, channels] corresponding to L=1, m=-1,0,1
    """
    # L=1 coefficients are at indices 1, 2, 3 (m=-1, 0, 1)
    return embedding[:, 1:4, :]

# %%
rot_matrix = random_rotation_matrix().to(torch.float64  )

# %%
rot_matrix.dtype
# Out:
# torch.float64

# %%
rot_matrix.shape
# Out:
# torch.Size([3, 3])

# %% [markdown]
# ## 1. The backbone model

# %%
from metalsitenn.nn.backbone import EquiformerWEdgesBackbone
# Out:
# /home/ekomp/.conda/envs/metal3/lib/python3.9/site-packages/fairchem/core/models/scn/spherical_harmonics.py:23: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   _Jd = torch.load(os.path.join(os.path.dirname(__file__), "Jd.pt"))
# /home/ekomp/.conda/envs/metal3/lib/python3.9/site-packages/fairchem/core/models/equiformer_v2/wigner.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   _Jd = torch.load(os.path.join(os.path.dirname(__file__), "Jd.pt"))

# %%
backbone = EquiformerWEdgesBackbone(
    feature_vocab_sizes=feature_vocab_sizes,
    atom_features=['element', 'charge', 'nhyd', 'hyb'],
    bond_features=['bond_order', 'is_in_ring', 'is_aromatic'],
    embedding_dim=32,
    use_topology_gradients=False,
    use_time=False,
    lmax_list=LMAX_LIST,
    sphere_channels=NUM_CHANNELS,
    mmax_list=MMAX_LIST,
    num_layers=2, # to avoid propegating numerican precision issues
)
# Out:
# WARNING:root:Parameter 'mmax_list=[3]' is ignored in EquiformerWEdgesBackbone. Reason: Mmax list is now derived from lmax list

# %% [markdown]
# ## 2. Move all datatypes to super high precision so we don't have to deal with numerical issues

# %%
backbone = backbone.double()

for param in backbone.parameters():
    if param.dtype.is_floating_point:
        param.data = param.data.double()
for buffer in backbone.buffers():
    if buffer.dtype.is_floating_point:
        buffer.data = buffer.data.double()

# %%
batch_double = copy.deepcopy(batch)
for attr_name, attr_value in batch_double.__dict__.items():
    if isinstance(attr_value, torch.Tensor) and attr_value.dtype.is_floating_point:
        setattr(batch_double, attr_name, attr_value.double())
batch = batch_double

# %% [markdown]
# Prepare rotated batch

# %%
rotated_batch = copy.deepcopy(batch)
rotated_batch.positions.dtype
# Out:
# torch.float64

# %%
rotated_positions = apply_rotation_to_positions(batch.positions, rot_matrix)
rotated_distance_vec = rotated_positions[batch.edge_index[:,1]] - rotated_positions[batch.edge_index[:,0]]
rotated_distances = torch.norm(rotated_distance_vec, dim=1).reshape(-1, 1)

# %%
torch.testing.assert_close(rotated_distances, batch.distances, rtol=1e-5, atol=1e-5)

# %% [markdown]
# distances are the first "feature" that should be invariant and indeed they are

# %%
rotated_batch.positions = rotated_positions
rotated_batch.distance_vec = rotated_distance_vec
rotated_batch.distances = rotated_distances

# %% [markdown]
# ## 3. get outputs from original batch and rotate it

# %%
outs = backbone(batch)['node_embedding'].embedding

# %%
outs_scalers = extract_scalar_features(outs)

# %%
outs_scalers.shape
# Out:
# torch.Size([91, 64])

# %%
outs_l1 = extract_vector_features(outs)

# %% [markdown]
# ## 4. Get outs from rotated batch and compare to original batch rotated

# %%
rotated_outs = backbone(rotated_batch)['node_embedding'].embedding

# %%
rotated_outs_scalers = extract_scalar_features(rotated_outs)
rotated_outs_l1 = extract_vector_features(rotated_outs)

# %%
torch.testing.assert_close(rotated_outs_scalers, outs_scalers, rtol=1e-3, atol=1e-5)
# .1% relative error and 1e-5 absolute error is acceptable for numerical precision

# %% [markdown]
# The rotated -> model -> outs are in spherical harmonics rotated, so we just need to extract the cartesian vector features

# %%
# convert from spherical to cartesian
rotated_outs_vectors = rotated_outs_l1.permute(0, 2, 1)

# %% [markdown]
# The model -> outs are in spherical harmonics UNROTATED, so we just need to extract the cartesian vector features and then rotated

# %%
outs_l1.shape
# Out:
# torch.Size([91, 3, 64])

# %%
outs_vectors = outs_l1.permute(0, 2, 1)
outs_vectors_rotated = apply_rotation_to_positions(outs_vectors, rot_matrix)

# %%
# rtol is high because rotation can put a vector nearly parallel to an axis, leading to extremelly small components of the vector highly
# sensitive to numerical precision
torch.testing.assert_close(outs_vectors_rotated, rotated_outs_vectors, rtol=1, atol=1e-5)

# %%
# plot rotated system with output vectors
visualize_protein_data_3d(
    protein_data=rotated_batch,
    velocities=rotated_outs_vectors[:,0,:].detach(),
    velocity_scale=5)
# Out:
# <div id="3dmolviewer_1755717825922143"  style="position: relative; width: 800px; height: 600px;">
#         <p id="3dmolwarning_1755717825922143" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.0/build/3Dmol-min.js');
# }
#
# var viewer_1755717825922143 = null;
# var warn = document.getElementById("3dmolwarning_1755717825922143");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1755717825922143 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1755717825922143"),{backgroundColor:"white"});
# viewer_1755717825922143.zoomTo();
# 	viewer_1755717825922143.setBackgroundColor("white");
# 	viewer_1755717825922143.addSphere({"center": {"x": 33.72313509970074, "y": 71.1834531256844, "z": -47.192311758847595}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_1755717825922143.addSphere({"center": {"x": 32.41599612979863, "y": 71.03517750483908, "z": -47.83224887875419}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755717825922143.addSphere({"center": {"x": 31.42737157052102, "y": 70.48422982827307, "z": -46.812731147295416}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755717825922143.addSphere({"center": {"x": 30.303848925802406, "y": 70.94879658778505, "z": -46.75351630313937}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_1755717825922143.addSphere({"center": {"x": 32.489335335296, "y": 70.14963593663737, "z": -49.09780518336267}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755717825922143.addSphere({"center": {"x": 31.07412303954392, "y": 69.70493542451996, "z": -49.54574100144235}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755717825922143.addSphere({"center": {"x": 33.18693024286616, "y": 70.92679187105055, "z": -50.211470075211665}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755717825922143.addSphere({"center": {"x": 31.81859142474109, "y": 69.49002931622915, "z": -46.03368931359797}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_1755717825922143.addSphere({"center": {"x": 30.9136436198999, "y": 68.89994539755011, "z": -45.03502963100076}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755717825922143.addSphere({"center": {"x": 31.807295248731364, "y": 68.15119372791352, "z": -44.0685478788706}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755717825922143.addSphere({"center": {"x": 32.50536495007608, "y": 67.20977159592213, "z": -44.45662833735435}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_1755717825922143.addSphere({"center": {"x": 29.86567104600064, "y": 67.97467386659409, "z": -45.72556067989724}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755717825922143.addSphere({"center": {"x": 29.05751210011113, "y": 67.02560368256503, "z": -44.71776232567102}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755717825922143.addSphere({"center": {"x": 29.04303323438698, "y": 67.21452442265644, "z": -43.52181308251674}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_1755717825922143.addSphere({"center": {"x": 28.426170515552247, "y": 66.02927622251318, "z": -45.11815179940537}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_1755717825922143.addSphere({"center": {"x": 31.815815680444192, "y": 68.57175684012752, "z": -42.816010394815855}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_1755717825922143.addSphere({"center": {"x": 32.76443880078906, "y": 67.98912178359663, "z": -41.77184425950601}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer
, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17557178286243227.addSphere({"center": {"x": 29.49659947379623, "y": 65.51940344236974, "z": -40.96707718366114}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178286243227.addSphere({"center": {"x": 29.369687599576164, "y": 65.86670573494258, "z": -40.444057035929966}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17557178286243227.addSphere({"center": {"x": 29.17657711129637, "y": 65.38746725085642, "z": -40.57248498098465}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178286243227.addSphere({"center": {"x": 34.036567318624364, "y": 63.59427762214678, "z": -39.59697155735452}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17557178286243227.addSphere({"center": {"x": 35.48403398409119, "y": 63.798144730078924, "z": -39.76853354221365}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178286243227.addSphere({"center": {"x": 36.24620761345026, "y": 63.29385133771876, "z": -38.571600726953044}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178286243227.addSphere({"center": {"x": 37.3737423504406, "y": 62.7307110682493, "z": -38.73487370419718}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17557178286243227.addSphere({"center": {"x": 35.82306756719045, "y": 65.29472157194742, "z": -39.995005948682966}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178286243227.addSphere({"center": {"x": 40.80431145763779, "y": 65.13767592190256, "z": -45.95267542344713}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17557178286243227.addSphere({"center": {"x": 40.21890089936915, "y": 64.64366893434455, "z": -47.1642120183463}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178286243227.addSphere({"center": {"x": 38.68127054955563, "y": 64.43535833750269, "z": -46.98924534663045}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178286243227.addSphere({"center": {"x": 37.902645997722225, "y": 64.95973183188717, "z": -47.79277696275368}, "rad

# %% [markdown]
# These are plenty accurate enough

# %% [markdown]
# ## 5. Repeat with topology gradients on

# %%
backbone = EquiformerWEdgesBackbone(
    feature_vocab_sizes=feature_vocab_sizes,
    atom_features=['element', 'charge', 'nhyd', 'hyb'],
    bond_features=['bond_order', 'is_in_ring', 'is_aromatic'],
    embedding_dim=32,
    use_topology_gradients=True,
    use_time=False,
    lmax_list=LMAX_LIST,
    sphere_channels=NUM_CHANNELS,
    mmax_list=MMAX_LIST,
    num_layers=2, # to avoid propegating numerican precision issues
)
# Out:
# WARNING:root:Parameter 'mmax_list=[3]' is ignored in EquiformerWEdgesBackbone. Reason: Mmax list is now derived from lmax list

# %%
backbone = backbone.double()

for param in backbone.parameters():
    if param.dtype.is_floating_point:
        param.data = param.data.double()
for buffer in backbone.buffers():
    if buffer.dtype.is_floating_point:
        buffer.data = buffer.data.double()

# %%
batch_double = copy.deepcopy(batch)
for attr_name, attr_value in batch_double.__dict__.items():
    if isinstance(attr_value, torch.Tensor) and attr_value.dtype.is_floating_point:
        setattr(batch_double, attr_name, attr_value.double())
batch = batch_double

# %% [markdown]
# Prepare rotated batch

# %%
rotated_batch = copy.deepcopy(batch)
rotated_batch.positions.dtype
# Out:
# torch.float64

# %%
rotated_positions = apply_rotation_to_positions(batch.positions, rot_matrix)
rotated_distance_vec = rotated_positions[batch.edge_index[:,1]] - rotated_positions[batch.edge_index[:,0]]
rotated_distances = torch.norm(rotated_distance_vec, dim=1).reshape(-1, 1)

# %%
torch.testing.assert_close(rotated_distances, batch.distances, rtol=1e-5, atol=1e-5)

# %% [markdown]
# distances are the first "feature" that should be invariant and indeed they are

# %%
rotated_batch.positions = rotated_positions
rotated_batch.distance_vec = rotated_distance_vec
rotated_batch.distances = rotated_distances

# %%
outs = backbone(batch)['node_embedding'].embedding

# %%
outs_scalers = extract_scalar_features(outs)

# %%
outs_scalers.shape
# Out:
# torch.Size([91, 64])

# %%
outs_l1 = extract_vector_features(outs)

# %%
rotated_outs = backbone(rotated_batch)['node_embedding'].embedding

# %%
rotated_outs_scalers = extract_scalar_features(rotated_outs)
rotated_outs_l1 = extract_vector_features(rotated_outs)

# %%
torch.testing.assert_close(rotated_outs_scalers, outs_scalers, rtol=1e-3, atol=1e-5)
# 1% relative error and 1e-4 absolute error is acceptable for numerical precision

# %% [markdown]
# The rotated -> model -> outs are in spherical harmonics rotated, so we just need to extract the cartesian vector features

# %%
# convert from spherical to cartesian
rotated_outs_vectors = rotated_outs_l1.permute(0, 2, 1)

# %% [markdown]
# The model -> outs are in spherical harmonics UNROTATED, so we just need to extract the cartesian vector features and then rotated

# %%
outs_l1.shape
# Out:
# torch.Size([91, 3, 64])

# %%
outs_vectors = outs_l1.permute(0, 2, 1)
outs_vectors_rotated = apply_rotation_to_positions(outs_vectors, rot_matrix)

# %%
# rtol is high because rotation can put a vector nearly parallel to an axis, leading to extremelly small components of the vector highly
# sensitive to numerical precision
torch.testing.assert_close(outs_vectors_rotated, rotated_outs_vectors, rtol=1, atol=1e-5)

# %%
# plot rotated system with output vectors
visualize_protein_data_3d(
    protein_data=rotated_batch,
    velocities=rotated_outs_vectors[:,0,:].detach(),
    velocity_scale=5)
# Out:
# <div id="3dmolviewer_17557178441882217"  style="position: relative; width: 800px; height: 600px;">
#         <p id="3dmolwarning_17557178441882217" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.0/build/3Dmol-min.js');
# }
#
# var viewer_17557178441882217 = null;
# var warn = document.getElementById("3dmolwarning_17557178441882217");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17557178441882217 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17557178441882217"),{backgroundColor:"white"});
# viewer_17557178441882217.zoomTo();
# 	viewer_17557178441882217.setBackgroundColor("white");
# 	viewer_17557178441882217.addSphere({"center": {"x": 33.72313509970074, "y": 71.1834531256844, "z": -47.192311758847595}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17557178441882217.addSphere({"center": {"x": 32.41599612979863, "y": 71.03517750483908, "z": -47.83224887875419}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178441882217.addSphere({"center": {"x": 31.42737157052102, "y": 70.48422982827307, "z": -46.812731147295416}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178441882217.addSphere({"center": {"x": 30.303848925802406, "y": 70.94879658778505, "z": -46.75351630313937}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17557178441882217.addSphere({"center": {"x": 32.489335335296, "y": 70.14963593663737, "z": -49.09780518336267}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178441882217.addSphere({"center": {"x": 31.07412303954392, "y": 69.70493542451996, "z": -49.54574100144235}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178441882217.addSphere({"center": {"x": 33.18693024286616, "y": 70.92679187105055, "z": -50.211470075211665}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178441882217.addSphere({"center": {"x": 31.81859142474109, "y": 69.49002931622915, "z": -46.03368931359797}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17557178441882217.addSphere({"center": {"x": 30.9136436198999, "y": 68.89994539755011, "z": -45.03502963100076}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17
, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178441882217.addSphere({"center": {"x": 38.68127054955563, "y": 64.43535833750269, "z": -46.98924534663045}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178441882217.addSphere({"center": {"x": 37.902645997722225, "y": 64.95973183188717, "z": -47.79277696275368}, "rad

# %%
visualize_protein_data_3d(
    protein_data=rotated_batch,
    velocities=outs_vectors_rotated[:,0,:].detach(),
    velocity_scale=5)
# Out:
# <div id="3dmolviewer_17557178448452735"  style="position: relative; width: 800px; height: 600px;">
#         <p id="3dmolwarning_17557178448452735" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.0/build/3Dmol-min.js');
# }
#
# var viewer_17557178448452735 = null;
# var warn = document.getElementById("3dmolwarning_17557178448452735");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17557178448452735 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17557178448452735"),{backgroundColor:"white"});
# viewer_17557178448452735.zoomTo();
# 	viewer_17557178448452735.setBackgroundColor("white");
# 	viewer_17557178448452735.addSphere({"center": {"x": 33.72313509970074, "y": 71.1834531256844, "z": -47.192311758847595}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 32.41599612979863, "y": 71.03517750483908, "z": -47.83224887875419}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 31.42737157052102, "y": 70.48422982827307, "z": -46.812731147295416}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 30.303848925802406, "y": 70.94879658778505, "z": -46.75351630313937}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 32.489335335296, "y": 70.14963593663737, "z": -49.09780518336267}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 31.07412303954392, "y": 69.70493542451996, "z": -49.54574100144235}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 33.18693024286616, "y": 70.92679187105055, "z": -50.211470075211665}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 31.81859142474109, "y": 69.49002931622915, "z": -46.03368931359797}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 30.9136436198999, "y": 68.89994539755011, "z": -45.03502963100076}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 31.807295248731364, "y": 68.15119372791352, "z": -44.0685478788706}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 32.50536495007608, "y": 67.20977159592213, "z": -44.45662833735435}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 29.86567104600064, "y": 67.97467386659409, "z": -45.72556067989724}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 29.05751210011113, "y": 67.02560368256503, "z": -44.71776232567102}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 29.04303323438698, "y": 67.21452442265644, "z": -43.52181308251674}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 28.426170515552247, "y": 66.02927622251318, "z": -45.11815179940537}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 31.815815680444192, "y": 68.57175684012752, "z": -42.816010394815855}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 32.76443880078906, "y": 67.98912178359663, "z": -41.77184425950601}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 32.12567493855975, "y": 66.80291304713656, "z": -40.999652563426736}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 32.696140672718805, "y": 66.29066459907527, "z": -40.112592741530634}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 33.19325098839783, "y": 69.089046953624, "z": -40.73921626804097}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 32.12590696326152, "y": 69.43904675914067, "z": -39.86371096510722}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 33.723020238170164, "y": 70.37415811196534, "z": -41.475902744596034}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 30.07373264777203, "y": 65.87012794109579, "z": -40.620451214643026}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 29.904326744100903, "y": 65.58585052977388, "z": -40.70786862456055}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 30.069322492326275, "y": 65.19270714976373, "z": -40.90428997653461}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 30.153914829586977, "y": 65.05761304553089, "z": -40.87773124997443}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 29.49659947379623, "y": 65.51940344236974, "z": -40.96707718366114}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 29.369687599576164, "y": 65.86670573494258, "z": -40.444057035929966}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 29.17657711129637, "y": 65.38746725085642, "z": -40.57248498098465}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 34.036567318624364, "y": 63.59427762214678, "z": -39.59697155735452}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 35.48403398409119, "y": 63.798144730078924, "z": -39.76853354221365}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 36.24620761345026, "y": 63.29385133771876, "z": -38.571600726953044}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 37.3737423504406, "y": 62.7307110682493, "z": -38.73487370419718}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 35.82306756719045, "y": 65.29472157194742, "z": -39.995005948682966}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 40.80431145763779, "y": 65.13767592190256, "z": -45.95267542344713}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 40.21890089936915, "y": 64.64366893434455, "z": -47.1642120183463}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 38.68127054955563, "y": 64.43535833750269, "z": -46.98924534663045}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178448452735.addSphere({"center": {"x": 37.902645997722225, "y": 64.95973183188717, "z": -47.79277696275368}, "rad

# %% [markdown]
# ## 6. Repeat but include time to make sure that the Film module doesn't mess things up ...

# %%
backbone = EquiformerWEdgesBackbone(
    feature_vocab_sizes=feature_vocab_sizes,
    atom_features=['element', 'charge', 'nhyd', 'hyb'],
    bond_features=['bond_order', 'is_in_ring', 'is_aromatic'],
    embedding_dim=32,
    num_layers=2,  # to avoid propagating numerical precision issues
    use_topology_gradients=True,
    use_time=True,  # include time to test Film module
    lmax_list=LMAX_LIST,
    sphere_channels=NUM_CHANNELS, film_basis_function='gaussian', film_num_gaussians=96)

# %%
# update precision
for param in backbone.parameters():
    if param.dtype.is_floating_point:
        param.data = param.data.double()
for buffer in backbone.buffers():
    if buffer.dtype.is_floating_point:
        buffer.data = buffer.data.double()

# %%
outs = backbone(batch)['node_embedding'].embedding
outs_scalers = extract_scalar_features(outs)
outs_l1 = extract_vector_features(outs)

# %%
rotated_outs = backbone(rotated_batch)['node_embedding'].embedding
rotated_outs_scalers = extract_scalar_features(rotated_outs)
rotated_outs_l1 = extract_vector_features(rotated_outs)

# %%
outs_vectors = outs_l1.permute(0, 2, 1)
outs_vectors_rotated = apply_rotation_to_positions(outs_vectors, rot_matrix)

# %%
rotated_outs_vectors = rotated_outs_l1.permute(0, 2, 1)

# %%
torch.testing.assert_close(outs_vectors_rotated, rotated_outs_vectors, rtol=1, atol=1e-5)

# %%
# plot rotated system with output vectors
visualize_protein_data_3d(
    protein_data=rotated_batch,
    velocities=rotated_outs_vectors[:,0,:].detach(),
    velocity_scale=10)
# Out:
# <div id="3dmolviewer_17557178646878567"  style="position: relative; width: 800px; height: 600px;">
#         <p id="3dmolwarning_17557178646878567" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.0/build/3Dmol-min.js');
# }
#
# var viewer_17557178646878567 = null;
# var warn = document.getElementById("3dmolwarning_17557178646878567");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17557178646878567 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17557178646878567"),{backgroundColor:"white"});
# viewer_17557178646878567.zoomTo();
# 	viewer_17557178646878567.setBackgroundColor("white");
# 	viewer_17557178646878567.addSphere({"center": {"x": 33.72313509970074, "y": 71.1834531256844, "z": -47.192311758847595}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 32.41599612979863, "y": 71.03517750483908, "z": -47.83224887875419}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 31.42737157052102, "y": 70.48422982827307, "z": -46.812731147295416}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 30.303848925802406, "y": 70.94879658778505, "z": -46.75351630313937}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 32.489335335296, "y": 70.14963593663737, "z": -49.09780518336267}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 31.07412303954392, "y": 69.70493542451996, "z": -49.54574100144235}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 33.18693024286616, "y": 70.92679187105055, "z": -50.211470075211665}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 31.81859142474109, "y": 69.49002931622915, "z": -46.03368931359797}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 30.9136436198999, "y": 68.89994539755011, "z": -45.03502963100076}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 31.807295248731364, "y": 68.15119372791352, "z": -44.0685478788706}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 32.50536495007608, "y": 67.20977159592213, "z": -44.45662833735435}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 29.86567104600064, "y": 67.97467386659409, "z": -45.72556067989724}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 29.05751210011113, "y": 67.02560368256503, "z": -44.71776232567102}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 29.04303323438698, "y": 67.21452442265644, "z": -43.52181308251674}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 28.426170515552247, "y": 66.02927622251318, "z": -45.11815179940537}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 31.815815680444192, "y": 68.57175684012752, "z": -42.816010394815855}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 32.76443880078906, "y": 67.98912178359663, "z": -41.77184425950601}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 32.12567493855975, "y": 66.80291304713656, "z": -40.999652563426736}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 32.696140672718805, "y": 66.29066459907527, "z": -40.112592741530634}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 33.19325098839783, "y": 69.089046953624, "z": -40.73921626804097}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 32.12590696326152, "y": 69.43904675914067, "z": -39.86371096510722}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 33.723020238170164, "y": 70.37415811196534, "z": -41.475902744596034}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 30.07373264777203, "y": 65.87012794109579, "z": -40.620451214643026}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 29.904326744100903, "y": 65.58585052977388, "z": -40.70786862456055}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 30.069322492326275, "y": 65.19270714976373, "z": -40.90428997653461}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 30.153914829586977, "y": 65.05761304553089, "z": -40.87773124997443}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 29.49659947379623, "y": 65.51940344236974, "z": -40.96707718366114}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 29.369687599576164, "y": 65.86670573494258, "z": -40.444057035929966}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 29.17657711129637, "y": 65.38746725085642, "z": -40.57248498098465}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 34.036567318624364, "y": 63.59427762214678, "z": -39.59697155735452}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 35.48403398409119, "y": 63.798144730078924, "z": -39.76853354221365}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 36.24620761345026, "y": 63.29385133771876, "z": -38.571600726953044}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 37.3737423504406, "y": 62.7307110682493, "z": -38.73487370419718}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 35.82306756719045, "y": 65.29472157194742, "z": -39.995005948682966}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 40.80431145763779, "y": 65.13767592190256, "z": -45.95267542344713}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 40.21890089936915, "y": 64.64366893434455, "z": -47.1642120183463}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 38.68127054955563, "y": 64.43535833750269, "z": -46.98924534663045}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_17557178646878567.addSphere({"center": {"x": 37.902645997722225, "y": 64.95973183188717, "z": -47.79277696275368}, "rad

# %%
visualize_protein_data_3d(
    protein_data=rotated_batch,
    velocities=outs_vectors_rotated[:,0,:].detach(),
    velocity_scale=10)
# Out:
# <div id="3dmolviewer_1755717865513935"  style="position: relative; width: 800px; height: 600px;">
#         <p id="3dmolwarning_1755717865513935" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.0/build/3Dmol-min.js');
# }
#
# var viewer_1755717865513935 = null;
# var warn = document.getElementById("3dmolwarning_1755717865513935");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer
, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755717865513935.addSphere({"center": {"x": 30.153914829586977, "y": 65.05761304553089, "z": -40.87773124997443}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_1755717865513935.addSphere({"center": {"x": 29.49659947379623, "y": 65.51940344236974, "z": -40.96707718366114}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755717865513935.addSphere({"center": {"x": 29.369687599576164, "y": 65.86670573494258, "z": -40.444057035929966}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_1755717865513935.addSphere({"center": {"x": 29.17657711129637, "y": 65.38746725085642, "z": -40.57248498098465}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755717865513935.addSphere({"center": {"x": 34.036567318624364, "y": 63.59427762214678, "z": -39.59697155735452}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_1755717865513935.addSphere({"center": {"x": 35.48403398409119, "y": 63.798144730078924, "z": -39.76853354221365}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755717865513935.addSphere({"center": {"x": 36.24620761345026, "y": 63.29385133771876, "z": -38.571600726953044}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755717865513935.addSphere({"center": {"x": 37.3737423504406, "y": 62.7307110682493, "z": -38.73487370419718}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	viewer_1755717865513935.addSphere({"center": {"x": 35.82306756719045, "y": 65.29472157194742, "z": -39.995005948682966}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755717865513935.addSphere({"center": {"x": 40.80431145763779, "y": 65.13767592190256, "z": -45.95267542344713}, "radius": 0.3, "color": "blue", "alpha": 0.8});
# 	viewer_1755717865513935.addSphere({"center": {"x": 40.21890089936915, "y": 64.64366893434455, "z": -47.1642120183463}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755717865513935.addSphere({"center": {"x": 38.68127054955563, "y": 64.43535833750269, "z": -46.98924534663045}, "radius": 0.3, "color": "gray", "alpha": 0.8});
# 	viewer_1755717865513935.addSphere({"center": {"x": 37.902645997722225, "y": 64.95973183188717, "z": -47.79277696275368}, "radius": 0.3, "color": "red", "alpha": 0.8});
# 	vi

# %%
coeffiecient_norms = backbone(batch)['film_norm']

# %%
coeffiecient_norms
# Out:
# tensor(4.3053e-05, dtype=torch.float64, grad_fn=<MeanBackward0>)

# %% [markdown]
# ## 6. Scaler node prediction head

# %%
backbone = EquiformerWEdgesBackbone(
    feature_vocab_sizes=feature_vocab_sizes,
    atom_features=['element', 'charge', 'nhyd', 'hyb'],
    bond_features=['bond_order', 'is_in_ring', 'is_aromatic'],
    embedding_dim=32,
    num_layers=2,  # to avoid propagating numerical precision issues
    use_topology_gradients=True,
    use_time=False,  # include time to test Film module
    lmax_list=LMAX_LIST,
    sphere_channels=NUM_CHANNELS, film_basis_function='gaussian', film_num_gaussians=96,
)

# %%
for param in backbone.parameters():
    if param.dtype.is_floating_point:
        param.data = param.data.double()
for buffer in backbone.buffers():
    if buffer.dtype.is_floating_point:
        buffer.data = buffer.data.double()

# %%
from metalsitenn.nn.heads.node_prediction import NodePredictionHead

# %%
head = NodePredictionHead(
    backbone=backbone,
    output_dim=5, # arbitrary
)

# %%
# increase head precision
for param in head.parameters():
    if param.dtype.is_floating_point:
        param.data = param.data.double()
for buffer in head.buffers():
    if buffer.dtype.is_floating_point:
        buffer.data = buffer.data.double()

# %%
outs = backbone(batch)['node_embedding']
scaler_head_outs = head(outs)

# %%
rotated_outs = backbone(rotated_batch)['node_embedding']
rotated_scaler_head_outs = head(rotated_outs)

# %%
torch.testing.assert_close(rotated_scaler_head_outs, scaler_head_outs, rtol=1e-5, atol=1e-5)
